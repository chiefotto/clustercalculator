# %% [markdown]
# ## Planning and updates for site
#
# cluster flow (single season) -> get daily game logs -> calculate kmeans, pca etc -> cluster -> output cluster file
#  do this for every season, generate analysis based on seaonality, compare what teams are most alike so far

# %% [markdown]
# ## To do
#
# combine clusters with dvp, label which spots tend to have an event(column stat, stl, blk, etc) happening
#
# also add dvp view to player view, as in when clicking a player it should show that dvp for the opp team and that position.
#
# redo clustering mechanics for dynamic updates
#
# player view-> add new states
#
#
# ### completed
#
# add dvp for teams and automatically find dvp spots for each team, maybe assign a score to rank the weaknesses  -> v1 completed
#
# generate player stat lines in player specific views -> projections--> v1 completed
#
# generate rankings in game/team view , rankings as this player will have the best performance etc -> v1 with dvp completed
#
#
# need to change game details roster table-> it should use game logs table data (that can be updated daily) using team ids passed in from the home pages session state, filter for those teams, then get unique names from that smaller game log table and create roster lists (so taking a subset of columns from the table like PLAYER_NAME team and TEAM_NAME)
#
# ^using that roster list i gen, i need to append position for players,
# i could do this two ways,
#
# make a request with the subset table from the game logs, and pass the player ids to an endpoint to get player data ( would be a large list of player ids and append to table)
#
# or
#
# use teamroster endpoint, get the team ids from the session state, then just map position from present players in the generated table from game logs, and then add position column
#
# idk which to choose, which way is better for caching and effeciency
#
# cursor solved this^
#
#
#
# ### info
#
# pg-sg -> G
#
# sg-sf -> G-F
#
# sf-pf -> F
#
# sf-pf-c -> F-C
#
# c -> C
